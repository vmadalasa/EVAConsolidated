# %% [markdown]
# <a href="https://colab.research.google.com/github/vmadalasa/EVA4S7/blob/master/Assignment_S7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

cuda = torch.cuda.is_available()
print("CUDA Available?", cuda)

# For Reproducibility
torch.manual_seed(1)

if cuda:
    torch.cuda.manual_seed(1)
print(torch.cuda.get_device_name(0))

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# Out:
# CUDA Available? True
# Tesla P100-PCIE-16GB

# %%
import data
train_loader, test_loader = data.loader(128)
data.display()
# Out:
# CUDA Available? True
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import model as m

# %%
# !pip install torchsummary
import summary
summary.summ(device)
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#          Dropout2d-4           [-1, 32, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#               ReLU-7           [-1, 32, 32, 32]               0
#          Dropout2d-8           [-1, 32, 32, 32]               0
#             Conv2d-9           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-10           [-1, 32, 32, 32]              64
#              ReLU-11           [-1, 32, 32, 32]               0
#         Dropout2d-12           [-1, 32, 32, 32]               0
#         MaxPool2d-13           [-1, 32, 16, 16]               0
#            Conv2d-14           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-15           [-1, 64, 16, 16]             128
#              ReLU-16           [-1, 64, 16, 16]               0
#         Dropout2d-17           [-1, 64, 16, 16]               0
#            Conv2d-18           [-1, 64, 16, 16]          36,864
#    DilationConv2d-19           [-1, 64, 16, 16]               0
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#              ReLU-21           [-1, 64, 16, 16]               0
#         Dropout2d-22           [-1, 64, 16, 16]               0
#            Conv2d-23           [-1, 64, 16, 16]             576
#            Conv2d-24           [-1, 64, 16, 16]           4,096
#    DeptwiseConv2d-25           [-1, 64, 16, 16]               0
#       BatchNorm2d-26           [-1, 64, 16, 16]             128
#              ReLU-27           [-1, 64, 16, 16]               0
#         Dropout2d-28           [-1, 64, 16, 16]               0
#         MaxPool2d-29             [-1, 64, 8, 8]               0
#            Conv2d-30             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-31             [-1, 64, 8, 8]             128
#              ReLU-32             [-1, 64, 8, 8]               0
#         Dropout2d-33             [-1, 64, 8, 8]               0
#            Conv2d-34             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-35             [-1, 64, 8, 8]             128
#              ReLU-36             [-1, 64, 8, 8]               0
#         Dropout2d-37             [-1, 64, 8, 8]               0
#            Conv2d-38             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-39             [-1, 64, 8, 8]             128
#              ReLU-40             [-1, 64, 8, 8]               0
#         Dropout2d-41             [-1, 64, 8, 8]               0
#         MaxPool2d-42             [-1, 64, 4, 4]               0
#            Conv2d-43             [-1, 64, 4, 4]          36,864
#       BatchNorm2d-44             [-1, 64, 4, 4]             128
#              ReLU-45             [-1, 64, 4, 4]               0
#         Dropout2d-46             [-1, 64, 4, 4]               0
#            Conv2d-47             [-1, 64, 4, 4]          36,864
#       BatchNorm2d-48             [-1, 64, 4, 4]             128
#              ReLU-49             [-1, 64, 4, 4]               0
#         Dropout2d-50             [-1, 64, 4, 4]               0
#         AvgPool2d-51             [-1, 64, 1, 1]               0
#            Conv2d-52             [-1, 10, 1, 1]             640
# ================================================================
# Total params: 265,440
# Trainable params: 265,440
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.41
# Params size (MB): 1.01
# Estimated Total Size (MB): 6.44
# ----------------------------------------------------------------

# %%
import train as tr
import test as te

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

model = m.Net(True).to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-5)
#scheduler = StepLR(optimizer, step_size= 10, gamma= 0.1)
epochs = 50

for epoch in range(epochs):
  print('EPOCH: ', epoch+1)
  tr.train(model, device, train_loader, optimizer, epoch)
  #scheduler.step()
  te.test(model, device, test_loader)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH:  1
# Loss=1.6386626958847046 Batch_id=390 Accuracy=32.02: 100%|██████████| 391/391 [00:18<00:00, 21.48it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.4439, Accuracy: 4637/10000 (46.37%)
#
# EPOCH:  2
# Loss=1.2570786476135254 Batch_id=390 Accuracy=46.00: 100%|██████████| 391/391 [00:18<00:00, 21.44it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.1704, Accuracy: 5776/10000 (57.76%)
#
# EPOCH:  3
# Loss=1.3416715860366821 Batch_id=390 Accuracy=54.09: 100%|██████████| 391/391 [00:18<00:00, 21.54it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.0219, Accuracy: 6357/10000 (63.57%)
#
# EPOCH:  4
# Loss=1.180057406425476 Batch_id=390 Accuracy=59.33: 100%|██████████| 391/391 [00:18<00:00, 21.58it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.9113, Accuracy: 6761/10000 (67.61%)
#
# EPOCH:  5
# Loss=1.0399067401885986 Batch_id=390 Accuracy=63.10: 100%|██████████| 391/391 [00:18<00:00, 21.68it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.8245, Accuracy: 7129/10000 (71.29%)
#
# EPOCH:  6
# Loss=0.9672664403915405 Batch_id=390 Accuracy=65.92: 100%|██████████| 391/391 [00:17<00:00, 21.76it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.7801, Accuracy: 7280/10000 (72.80%)
#
# EPOCH:  7
# Loss=1.081569790840149 Batch_id=390 Accuracy=67.94: 100%|██████████| 391/391 [00:17<00:00, 21.86it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.7280, Accuracy: 7443/10000 (74.43%)
#
# EPOCH:  8
# Loss=0.7896322011947632 Batch_id=390 Accuracy=69.77: 100%|██████████| 391/391 [00:18<00:00, 21.46it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.7016, Accuracy: 7570/10000 (75.70%)
#
# EPOCH:  9
# Loss=0.7801321148872375 Batch_id=390 Accuracy=71.35: 100%|██████████| 391/391 [00:18<00:00, 21.68it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.6763, Accuracy: 7654/10000 (76.54%)
#
# EPOCH:  10
# Loss=0.7498793005943298 Batch_id=390 Accuracy=72.42: 100%|██████████| 391/391 [00:17<00:00, 21.79it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.6682, Accuracy: 7697/10000 (76.97%)
#
# EPOCH:  11
# Loss=0.6436959505081177 Batch_id=390 Accuracy=73.82: 100%|██████████| 391/391 [00:17<00:00, 21.80it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.6387, Accuracy: 7780/10000 (77.80%)
#
# EPOCH:  12
# Loss=0.8071931600570679 Batch_id=390 Accuracy=74.91: 100%|██████████| 391/391 [00:17<00:00, 21.85it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.6035, Accuracy: 7906/10000 (79.06%)
#
# EPOCH:  13
# Loss=0.9271702766418457 Batch_id=390 Accuracy=75.49: 100%|██████████| 391/391 [00:17<00:00, 21.88it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.6102, Accuracy: 7928/10000 (79.28%)
#
# EPOCH:  14
# Loss=0.6751333475112915 Batch_id=390 Accuracy=76.18: 100%|██████████| 391/391 [00:18<00:00, 21.68it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5925, Accuracy: 7941/10000 (79.41%)
#
# EPOCH:  15
# Loss=0.5375101566314697 Batch_id=390 Accuracy=77.10: 100%|██████████| 391/391 [00:18<00:00, 21.71it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5567, Accuracy: 8101/10000 (81.01%)
#
# EPOCH:  16
# Loss=0.7934352159500122 Batch_id=390 Accuracy=77.64: 100%|██████████| 391/391 [00:17<00:00, 21.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5543, Accuracy: 8100/10000 (81.00%)
#
# EPOCH:  17
# Loss=0.740750253200531 Batch_id=390 Accuracy=77.92: 100%|██████████| 391/391 [00:17<00:00, 21.81it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5448, Accuracy: 8150/10000 (81.50%)
#
# EPOCH:  18
# Loss=0.4919067919254303 Batch_id=390 Accuracy=78.65: 100%|██████████| 391/391 [00:17<00:00, 22.11it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5391, Accuracy: 8183/10000 (81.83%)
#
# EPOCH:  19
# Loss=0.868741512298584 Batch_id=390 Accuracy=79.13: 100%|██████████| 391/391 [00:17<00:00, 21.95it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5385, Accuracy: 8170/10000 (81.70%)
#
# EPOCH:  20
# Loss=0.7122211456298828 Batch_id=390 Accuracy=79.77: 100%|██████████| 391/391 [00:17<00:00, 21.96it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5181, Accuracy: 8250/10000 (82.50%)
#
# EPOCH:  21
# Loss=0.5976601839065552 Batch_id=390 Accuracy=80.11: 100%|██████████| 391/391 [00:17<00:00, 22.17it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5273, Accuracy: 8219/10000 (82.19%)
#
# EPOCH:  22
# Loss=0.4937136769294739 Batch_id=390 Accuracy=80.46: 100%|██████████| 391/391 [00:17<00:00, 22.13it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5130, Accuracy: 8245/10000 (82.45%)
#
# EPOCH:  23
# Loss=0.6273173093795776 Batch_id=390 Accuracy=80.89: 100%|██████████| 391/391 [00:17<00:00, 21.91it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5073, Accuracy: 8299/10000 (82.99%)
#
# EPOCH:  24
# Loss=0.6520644426345825 Batch_id=390 Accuracy=81.17: 100%|██████████| 391/391 [00:17<00:00, 21.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5216, Accuracy: 8222/10000 (82.22%)
#
# EPOCH:  25
# Loss=0.5892457962036133 Batch_id=390 Accuracy=81.60: 100%|██████████| 391/391 [00:17<00:00, 22.15it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5022, Accuracy: 8357/10000 (83.57%)
#
# EPOCH:  26
# Loss=0.5811818242073059 Batch_id=390 Accuracy=81.83: 100%|██████████| 391/391 [00:17<00:00, 22.18it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5116, Accuracy: 8295/10000 (82.95%)
#
# EPOCH:  27
# Loss=0.4260479807853699 Batch_id=390 Accuracy=82.42: 100%|██████████| 391/391 [00:17<00:00, 22.03it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5036, Accuracy: 8318/10000 (83.18%)
#
# EPOCH:  28
# Loss=0.5641905665397644 Batch_id=390 Accuracy=82.73: 100%|██████████| 391/391 [00:17<00:00, 22.64it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5098, Accuracy: 8278/10000 (82.78%)
#
# EPOCH:  29
# Loss=0.5079798102378845 Batch_id=390 Accuracy=82.83: 100%|██████████| 391/391 [00:16<00:00, 23.06it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4968, Accuracy: 8343/10000 (83.43%)
#
# EPOCH:  30
# Loss=0.3657374978065491 Batch_id=390 Accuracy=83.16: 100%|██████████| 391/391 [00:17<00:00, 22.83it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4888, Accuracy: 8374/10000 (83.74%)
#
# EPOCH:  31
# Loss=0.3241690993309021 Batch_id=390 Accuracy=83.35: 100%|██████████| 391/391 [00:17<00:00, 22.55it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5004, Accuracy: 8333/10000 (83.33%)
#
# EPOCH:  32
# Loss=0.7036362886428833 Batch_id=390 Accuracy=83.54: 100%|██████████| 391/391 [00:17<00:00, 22.47it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4899, Accuracy: 8386/10000 (83.86%)
#
# EPOCH:  33
# Loss=0.3885239362716675 Batch_id=390 Accuracy=83.74: 100%|██████████| 391/391 [00:17<00:00, 22.58it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4801, Accuracy: 8391/10000 (83.91%)
#
# EPOCH:  34
# Loss=0.5822411775588989 Batch_id=390 Accuracy=84.02: 100%|██████████| 391/391 [00:16<00:00, 23.17it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.5013, Accuracy: 8343/10000 (83.43%)
#
# EPOCH:  35
# Loss=0.6662269830703735 Batch_id=390 Accuracy=83.93: 100%|██████████| 391/391 [00:17<00:00, 22.68it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4717, Accuracy: 8478/10000 (84.78%)
#
# EPOCH:  36
# Loss=0.44666600227355957 Batch_id=390 Accuracy=84.36: 100%|██████████| 391/391 [00:17<00:00, 22.92it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4972, Accuracy: 8346/10000 (83.46%)
#
# EPOCH:  37
# Loss=0.49717384576797485 Batch_id=390 Accuracy=84.28: 100%|██████████| 391/391 [00:17<00:00, 22.84it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4874, Accuracy: 8381/10000 (83.81%)
#
# EPOCH:  38
# Loss=0.4136168360710144 Batch_id=390 Accuracy=84.75: 100%|██████████| 391/391 [00:17<00:00, 22.81it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4702, Accuracy: 8473/10000 (84.73%)
#
# EPOCH:  39
# Loss=0.5352773666381836 Batch_id=390 Accuracy=84.92: 100%|██████████| 391/391 [00:17<00:00, 22.51it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4800, Accuracy: 8448/10000 (84.48%)
#
# EPOCH:  40
# Loss=0.4628738760948181 Batch_id=390 Accuracy=85.04: 100%|██████████| 391/391 [00:16<00:00, 23.14it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4728, Accuracy: 8495/10000 (84.95%)
#
# EPOCH:  41
# Loss=0.4783903658390045 Batch_id=390 Accuracy=85.24: 100%|██████████| 391/391 [00:17<00:00, 22.80it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4704, Accuracy: 8484/10000 (84.84%)
#
# EPOCH:  42
# Loss=0.5051069259643555 Batch_id=390 Accuracy=85.55: 100%|██████████| 391/391 [00:16<00:00, 23.17it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4884, Accuracy: 8393/10000 (83.93%)
#
# EPOCH:  43
# Loss=0.4049623906612396 Batch_id=390 Accuracy=85.58: 100%|██████████| 391/391 [00:17<00:00, 22.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4756, Accuracy: 8472/10000 (84.72%)
#
# EPOCH:  44
# Loss=0.3179057836532593 Batch_id=390 Accuracy=85.62: 100%|██████████| 391/391 [00:17<00:00, 22.82it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4704, Accuracy: 8484/10000 (84.84%)
#
# EPOCH:  45
# Loss=0.42940711975097656 Batch_id=390 Accuracy=85.93: 100%|██████████| 391/391 [00:16<00:00, 23.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4752, Accuracy: 8469/10000 (84.69%)
#
# EPOCH:  46
# Loss=0.4655407965183258 Batch_id=390 Accuracy=85.80: 100%|██████████| 391/391 [00:17<00:00, 22.02it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4770, Accuracy: 8443/10000 (84.43%)
#
# EPOCH:  47
# Loss=0.3637031316757202 Batch_id=390 Accuracy=86.20: 100%|██████████| 391/391 [00:17<00:00, 22.09it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4801, Accuracy: 8451/10000 (84.51%)
#
# EPOCH:  48
# Loss=0.5383556485176086 Batch_id=390 Accuracy=86.25: 100%|██████████| 391/391 [00:17<00:00, 21.96it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4726, Accuracy: 8466/10000 (84.66%)
#
# EPOCH:  49
# Loss=0.420553594827652 Batch_id=390 Accuracy=86.35: 100%|██████████| 391/391 [00:18<00:00, 21.63it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.4638, Accuracy: 8495/10000 (84.95%)
#
# EPOCH:  50
# Loss=0.46272745728492737 Batch_id=390 Accuracy=86.66: 100%|██████████| 391/391 [00:18<00:00, 21.53it/s]
# Test set: Average loss: 0.4702, Accuracy: 8498/10000 (84.98%)

# %%
import utilis as ut
path = '/classifier.pt'
saved_model = m.Net(gbn= True).to(device)
saved_model.load_state_dict(torch.load(path))
saved_model.eval()
ut.mis(saved_model, device, test_loader, 25)
# Out:
# Test set: Average loss: 0.4702, Accuracy: 8498/10000 (84.98%)
#
# (1502, 32, 32, 3)

# %%
ut.graph()

# %%
ut.testvtrain()

# %%
ut.class_acc(saved_model,device, test_loader)
# Out:
# Accuracy of plane : 84 %
# Accuracy of   car : 92 %
# Accuracy of  bird : 77 %
# Accuracy of   cat : 67 %
# Accuracy of  deer : 84 %
# Accuracy of   dog : 80 %
# Accuracy of  frog : 91 %
# Accuracy of horse : 86 %
# Accuracy of  ship : 92 %
# Accuracy of truck : 92 %
